# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.subplot(2,2,1)
plt.plot(x,y,color="m") 



plt.subplot(2,2,2)
plt.pie([1],colors="m")

x1=[2,4,6,8,10]
plt.subplot(2,2,3)
plt.pie(x1)



x2=[1,2,3,4,5]
y2=[1,2,3,4,5]
plt.subplot(2,2,4)
plt.bar(x,y)



plt.show()
