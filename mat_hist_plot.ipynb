# %%
import matplotlib.pyplot as plt
import numpy as np
import random
x=np.random.randint(10,70,(50))
print(x)
# Out:
# [18 15 11 52 29 54 42 20 48 25 36 12 26 42 59 61 63 12 49 38 25 57 18 13
#  42 41 52 20 68 46 24 13 63 45 65 10 66 18 52 48 29 34 64 53 62 50 56 60
#  12 31]

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
plt.hist(number)
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
plt.hist(number,color="g",edgecolor="r")
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l)                       #bins is used to collect data in given l value.
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,"auto",(0,200),edgecolor="r")                #0 to 200 is the range and bins is auto.             
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l)                       #bins is used .
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r")                       #bins is  not used.
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,cumulative=-1)              # cumulative used to covert the frequency parameter.         .
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,cumulative=-1,bottom=10)              #  bottom value start with 10..         .
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,cumulative=-1,bottom=10,align="left")                 # align is two types left and mid.     .
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,histtype="step")           
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,histtype="stepfilled")               
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,histtype="barstacked")                
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,histtype="barstacked",orientation="horizontal")                #orientation is used to chnage horizontal.      
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,rwidth=0.8)                  #rwidth is used the 0.8 difference between two graph.   .
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,rwidth=0.8,log="true")                    .
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.show()

# %%
c

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,label="plot")                  # label is used to show the plot and it always write with the legen function. .
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.legend()
plt.show()

# %%
number=[18,15,11,52,29,54,42,20,48,25,36,12,26,42,59,61,63,12,49,38,25,57,18,13,
 42,41,52,20,68,46,24,13,63,45,65,10,66,18,52,48,29,34,64,53,62,50,56,60,
 12,31]
l=[10,20,30,40,50,60,70]
plt.hist(number,color="g",edgecolor="r",bins=l,label="plot")                
plt.xlabel("python")
plt.ylabel("No.")
plt.title("hist_graph")
plt.axvline(55,color="y",label="line")                            # axvline used to seprate the data and the 55 means mujhe yaha pr krna g and color uska yellow krna h
plt.legend()
plt.show()
